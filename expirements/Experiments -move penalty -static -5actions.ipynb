# %%
from qlearning import run_experiment
from env import layout_original, layout_original_walled, layout_nowalls
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Expirments move penalty, static env, 5 actions

# %%
SIZE = 11
LAYOUT = layout_original_walled
SHOW = False
EPISODES = 500
N_ACTIONS = 5
DYNAMIC = False
DISCOUNT = 0.95
MOVE_PENALTY = -1
TARGET_REWARD = 25
WALL_PENALTY = -5
RS_PENALTY = -1
SHOW_EVERY = 100
EPSILON_START=0.3
EPSILON_END=0.01
LEARNING_RATE_START = 0.2
LEARNING_RATE_END = 0.05
SAVE_Q_TABLE = False
SAVE_RESULTS = True

n_experiments = 10

# %%
DF_Unshielded_QL = pd.DataFrame()
for i in range(n_experiments):
    Unshielded_QL = run_experiment(SHIELD_ON = False,
                                   CQL = False,
                                   RS = False,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Unshielded_QL)
    DF_Unshielded_QL = DF_Unshielded_QL.append(tmp_df)

DF_Unshielded_QL.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -81.58
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 4.91
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 7.06
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.08
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -73.74
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 4.14
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 8.67
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 10.02
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -66.33
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 3.99
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 6.96
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.37
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -79.76
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 3.83
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 6.72
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.69
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -86.86
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 0.9
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 7.61
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.41
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -82.54
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 3.66
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 7.42
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.15
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -76.45
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 1.57
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 7.8
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.68
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -75.3
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 1.43
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 7.63
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.63
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -84.6
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 4.62
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 6.24
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 9.79
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -80.33
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 4.41
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 7.52
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 10.28
# Results and image saved as: Unshielded_QL

# %%
DF_Shielded_QL = pd.DataFrame()
for i in range(n_experiments):
    Shielded_QL = run_experiment(SHIELD_ON = True,
                                   CQL = False,
                                   RS = False,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Shielded_QL)
    DF_Shielded_QL = DF_Shielded_QL.append(tmp_df)

DF_Shielded_QL.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -99.64
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -99.37
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -99.23
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL

# %%
DF_Shielded_CQL = pd.DataFrame()
for i in range(n_experiments):
    Shielded_CQL = run_experiment(SHIELD_ON = True,
                                   CQL = True,
                                   RS = True,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Shielded_CQL)
    DF_Shielded_CQL = DF_Shielded_CQL.append(tmp_df)

DF_Shielded_CQL.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -50.31
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.25
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.95
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.01
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -35.76
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.98
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.83
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.19
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -42.44
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 6.8
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.27
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.08
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -44.13
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.5
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.99
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.28
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -49.57
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.29
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.95
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.6
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -51.55
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.82
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.41
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.57
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -46.5
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.58
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.68
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.24
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -45.5
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.84
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.99
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 10.88
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -50.36
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.96
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.16
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.36
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -51.88
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.3
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.15
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.15
# Results and image saved as: Shielded_CQL

# %%
DF_Shielded_QL_RS = pd.DataFrame()
for i in range(n_experiments):
    Shielded_QL_RS = run_experiment(SHIELD_ON = True,
                                   CQL = False,
                                   RS = True,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Shielded_QL_RS)
    DF_Shielded_QL_RS = DF_Shielded_QL_RS.append(tmp_df)

DF_Shielded_QL_RS.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -45.55
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.06
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.15
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.49
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -48.3
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.15
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.3
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 10.66
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -46.8
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.04
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.19
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.41
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -47.65
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.42
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.09
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.54
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -48.44
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.66
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.21
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.38
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -44.72
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.09
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.38
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 10.65
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -45.69
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 9.01
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.3
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.6
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -47.24
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 6.59
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.2
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.07
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -44.83
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.95
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.93
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.06
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 5, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -50.88
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.05
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 9.51
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 11.17
# Results and image saved as: Shielded_QL_RS

# %% [markdown]
# ## Plot together

# %%
agents = [(DF_Unshielded_QL[DF_Unshielded_QL["index"] != 0], "Unshielded_QL"),
         (DF_Shielded_QL[DF_Shielded_QL["index"]!=0], "Shielded_QL"),
         (DF_Shielded_QL_RS[DF_Shielded_QL_RS["index"]!=0], "Shielded_QL_RS"),
         (DF_Shielded_CQL[DF_Shielded_CQL["index"]!=0], "Shielded_CQL")]

sns.set_theme(style="darkgrid")



for agent_data in agents:
    ax = sns.lineplot(data=agent_data[0], x="index", y=0, err_style="band", legend="brief",label=f"{agent_data[1]}")

    
ax.set(xlabel='Episodes', ylabel=f"Rewards {SHOW_EVERY} episodes moving avg", title='')
plt.show()

# %% [markdown]
# # Individual data

# %% [markdown]
# ## Data Unshielded_QL

# %%
mean = DF_Unshielded_QL.groupby('index').mean()
mean_overall = DF_Unshielded_QL.groupby('index').mean().mean()
maximum = DF_Unshielded_QL.max()
minimum = DF_Unshielded_QL.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -200
# maximum: 13
# mean overall: -9.309181636726546
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -170.0
# 2     -141.5
# 3     -155.9
# 4     -159.7
# ...      ...
# 496     12.3
# 497     12.5
# 498     13.0
# 499     12.3
# 500     12.5
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Data Shielded_QL

# %%
mean = DF_Shielded_QL.groupby('index').mean()
mean_overall = DF_Shielded_QL.groupby('index').mean().mean()
maximum = DF_Shielded_QL.max()
minimum = DF_Shielded_QL.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -100
# maximum: 0
# mean overall: -99.76526946107785
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -100.0
# 2     -100.0
# 3     -100.0
# 4      -95.0
# ...      ...
# 496   -100.0
# 497   -100.0
# 498   -100.0
# 499   -100.0
# 500   -100.0
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Data Shielded_CQL

# %%
mean = DF_Shielded_CQL.groupby('index').mean()
mean_overall = DF_Shielded_CQL.groupby('index').mean().mean()
maximum = DF_Shielded_CQL.max()
minimum = DF_Shielded_CQL.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -100
# maximum: 13
# mean overall: -1.159081836327341
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -100.0
# 2     -100.0
# 3     -100.0
# 4      -95.4
# ...      ...
# 496     12.6
# 497     12.6
# 498     12.1
# 499     12.3
# 500     12.5
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Data Shielded_QL_RS

# %%
mean = DF_Shielded_QL_RS.groupby('index').mean()
mean_overall = DF_Shielded_QL_RS.groupby('index').mean().mean()
maximum = DF_Shielded_QL_RS.max()
minimum = DF_Shielded_QL_RS.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -100
# maximum: 13
# mean overall: -1.0946107784431018
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -100.0
# 2     -100.0
# 3      -96.3
# 4      -95.7
# ...      ...
# 496     12.5
# 497     12.7
# 498     12.5
# 499     12.6
# 500     12.7
#
# [501 rows x 1 columns]
