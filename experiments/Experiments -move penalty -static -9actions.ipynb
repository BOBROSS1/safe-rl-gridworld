# %%
from qlearning import run_experiment
from env import layout_original, layout_original_walled, layout_nowalls
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Expirments move penalty, static env, 9 actions

# %%
SIZE = 11
LAYOUT = layout_original_walled
SHOW = False
EPISODES = 500
N_ACTIONS = 9
DYNAMIC = False
DISCOUNT = 0.95
MOVE_PENALTY = -1
TARGET_REWARD = 25
WALL_PENALTY = -5
RS_PENALTY = -1
SHOW_EVERY = 100
EPSILON_START=0.3
EPSILON_END=0.01
LEARNING_RATE_START = 0.2
LEARNING_RATE_END = 0.05
SAVE_Q_TABLE = False
SAVE_RESULTS = True

n_experiments = 10

# %%
DF_Unshielded_QL = pd.DataFrame()
for i in range(n_experiments):
    Unshielded_QL = run_experiment(SHIELD_ON = False,
                                   CQL = False,
                                   RS = False,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Unshielded_QL)
    DF_Unshielded_QL = DF_Unshielded_QL.append(tmp_df)

DF_Unshielded_QL.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -74.85
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.29
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 11.46
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 13.74
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -88.98
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.9
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 11.96
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.42
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -71.18
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 9.89
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 11.88
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.46
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -75.15
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.83
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 12.38
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 13.68
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -80.66
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.5
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 11.52
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.54
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -85.3
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.57
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 12.02
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 13.83
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -71.06
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 7.62
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 11.66
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.5
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -82.42
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 4.6
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 12.67
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.59
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -62.49
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 9.29
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 12.51
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 13.93
# Results and image saved as: Unshielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: False, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -75.03
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 8.36
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 10.14
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 13.98
# Results and image saved as: Unshielded_QL

# %%
DF_Shielded_QL = pd.DataFrame()
for i in range(n_experiments):
    Shielded_QL = run_experiment(SHIELD_ON = True,
                                   CQL = False,
                                   RS = False,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Shielded_QL)
    DF_Shielded_QL = DF_Shielded_QL.append(tmp_df)

DF_Shielded_QL.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -99.01
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -99.33
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -99.36
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -99.47
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -100.0
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -100.0
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: -100.0
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: -100.0
# Results and image saved as: Shielded_QL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: False, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -85.77
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: -3.89
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 6.3
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 8.04
# Results and image saved as: Shielded_QL

# %%
DF_Shielded_CQL = pd.DataFrame()
for i in range(n_experiments):
    Shielded_CQL = run_experiment(SHIELD_ON = True,
                                   CQL = True,
                                   RS = True,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Shielded_CQL)
    DF_Shielded_CQL = DF_Shielded_CQL.append(tmp_df)

DF_Shielded_CQL.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -44.01
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.49
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.81
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.94
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -40.88
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.46
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.94
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.72
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -39.4
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.63
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 13.98
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.6
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -37.61
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.01
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.17
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.98
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -31.27
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.87
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.52
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.48
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -43.19
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 11.7
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 15.21
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.39
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -45.94
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.75
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.88
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.58
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -40.3
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.85
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.41
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.53
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -33.96
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.08
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 13.8
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.59
# Results and image saved as: Shielded_CQL
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: True, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -37.68
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.61
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.1
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.79
# Results and image saved as: Shielded_CQL

# %%
DF_Shielded_QL_RS = pd.DataFrame()
for i in range(n_experiments):
    Shielded_QL_RS = run_experiment(SHIELD_ON = True,
                                   CQL = False,
                                   RS = True,
                                   start_q_table = None,
                                   SIZE = SIZE, LAYOUT = LAYOUT, SHOW = SHOW, EPISODES = EPISODES,
                                   N_ACTIONS = N_ACTIONS, DYNAMIC=DYNAMIC, DISCOUNT = DISCOUNT,
                                   MOVE_PENALTY = MOVE_PENALTY, TARGET_REWARD = TARGET_REWARD, 
                                   WALL_PENALTY = WALL_PENALTY, RS_PENALTY = RS_PENALTY, SHOW_EVERY = SHOW_EVERY,
                                   EPSILON_START=EPSILON_START, EPSILON_END=EPSILON_END,
                                   LEARNING_RATE_START = LEARNING_RATE_START, LEARNING_RATE_END = LEARNING_RATE_END,
                                   SAVE_Q_TABLE = SAVE_Q_TABLE, SAVE_RESULTS = SAVE_RESULTS)
    tmp_df = pd.DataFrame(Shielded_QL_RS)
    DF_Shielded_QL_RS = DF_Shielded_QL_RS.append(tmp_df)

DF_Shielded_QL_RS.reset_index(inplace=True)
# Out:
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -38.67
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.2
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.56
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.45
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -29.89
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.97
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.88
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.79
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -49.62
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.33
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.64
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.18
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -36.49
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.84
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.98
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.72
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -33.29
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.63
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 13.97
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.15
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -28.31
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.31
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.6
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.76
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -41.33
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.08
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 13.47
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 14.76
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -26.47
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.19
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 14.78
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.88
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -34.26
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 12.64
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 13.96
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.27
# Results and image saved as: Shielded_QL_RS
# Agent summary --> Size: 11, Episodes: 500, SHIELD_ON: True, CQL: False, N_ACTION: 9, DISCOUNT: 0.95,	MOVE_PENALTY: -1, TARGET_REWARD: 25, WALL_PENALTY: -5, RS: True, RS_PENALTY: -1
# Episode: 0, epsilon: 0.3, lr: 0.2, mean reward: 0.0
# Episode: 100, epsilon: 0.242, lr: 0.16993987975951905, mean reward: -45.73
# Episode: 200, epsilon: 0.184, lr: 0.13987975951903808, mean reward: 13.19
# Episode: 300, epsilon: 0.126, lr: 0.10981963927855712, mean reward: 13.65
# Episode: 400, epsilon: 0.06799999999999998, lr: 0.07975951903807615, mean reward: 15.55
# Results and image saved as: Shielded_QL_RS

# %% [markdown]
# ## Plot together

# %%
agents = [(DF_Unshielded_QL[DF_Unshielded_QL["index"] != 0], "Unshielded_QL"),
         (DF_Shielded_QL[DF_Shielded_QL["index"]!=0], "Shielded_QL"),
         (DF_Shielded_QL_RS[DF_Shielded_QL_RS["index"]!=0], "Shielded_QL_RS"),
         (DF_Shielded_CQL[DF_Shielded_CQL["index"]!=0], "Shielded_CQL")]

sns.set_theme(style="darkgrid")



for agent_data in agents:
    ax = sns.lineplot(data=agent_data[0], x="index", y=0, err_style="band", legend="brief",label=f"{agent_data[1]}")

    
ax.set(xlabel='Episodes', ylabel=f"Rewards {SHOW_EVERY} episodes moving avg", title='')
plt.show()

# %% [markdown]
# # Individual data

# %% [markdown]
# ## Data Unshielded_QL

# %%
mean = DF_Unshielded_QL.groupby('index').mean()
mean_overall = DF_Unshielded_QL.groupby('index').mean().mean()
maximum = DF_Unshielded_QL.max()
minimum = DF_Unshielded_QL.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -284
# maximum: 17
# mean overall: -5.36966067864272
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -222.4
# 2     -210.8
# 3     -192.1
# 4     -200.8
# ...      ...
# 496     16.8
# 497     17.0
# 498     16.5
# 499     17.0
# 500     17.0
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Data Shielded_QL

# %%
mean = DF_Shielded_QL.groupby('index').mean()
mean_overall = DF_Shielded_QL.groupby('index').mean().mean()
maximum = DF_Shielded_QL.max()
minimum = DF_Shielded_QL.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -100
# maximum: 16
# mean overall: -91.09321357285455
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -100.0
# 2     -100.0
# 3     -100.0
# 4     -100.0
# ...      ...
# 496    -88.9
# 497    -88.9
# 498    -88.9
# 499    -88.9
# 500    -88.9
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Data Shielded_CQL

# %%
mean = DF_Shielded_CQL.groupby('index').mean()
mean_overall = DF_Shielded_CQL.groupby('index').mean().mean()
maximum = DF_Shielded_CQL.max()
minimum = DF_Shielded_CQL.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -100
# maximum: 17
# mean overall: 3.8471057884231517
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1     -100.0
# 2     -100.0
# 3      -93.9
# 4     -100.0
# ...      ...
# 496     16.3
# 497     16.2
# 498     16.3
# 499     16.6
# 500     16.3
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Data Shielded_QL_RS

# %%
mean = DF_Shielded_QL_RS.groupby('index').mean()
mean_overall = DF_Shielded_QL_RS.groupby('index').mean().mean()
maximum = DF_Shielded_QL_RS.max()
minimum = DF_Shielded_QL_RS.min()

print("minimum:", minimum.values[1])
print("maximum:", maximum.values[1]) 
print("mean overall:", mean_overall[0])
print("mean per episode (over all episodes): ", mean)
# Out:
# minimum: -100
# maximum: 17
# mean overall: 4.543512974051897
# mean per episode (over all episodes):             0
# index
# 0        0.0
# 1      -93.5
# 2     -100.0
# 3     -100.0
# 4      -96.3
# ...      ...
# 496     16.7
# 497     16.5
# 498     16.7
# 499     15.8
# 500     16.6
#
# [501 rows x 1 columns]
